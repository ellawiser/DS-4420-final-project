# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# CSV
path = "/Users/ellawiser/Desktop/DS-4420-final-project/Data/cancer_image_csv_data/breast_cancer_images.csv"
df = pd.read_csv(path)

# colors
colors = ["#ff1493", "#ffb6c1"]   

plt.figure(figsize=(6, 8))

sns.countplot(
    data=df,
    x="classification",
    palette=colors
)

plt.title("Image Count by Class", fontsize=20)
plt.xlabel("Class", fontsize=20)
plt.ylabel("Count", fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.show()
# Out:
# /var/folders/7m/_kwszytx2sl5b9mqwf4gr9xm0000gn/T/ipykernel_6223/1712467434.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
