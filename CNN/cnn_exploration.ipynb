# %%
## exploring data and testing out CNN methods

# %%
import pandas as pd

# %%
dicom_data = pd.read_csv('Data/cbis-ddsm-breast-cancer-image-dataset/csv/dicom_info.csv')
image_dir = 'Data/cbis-ddsm-breast-cancer-image-dataset/jpeg'
